# %%
print("i. Discuss your learnings on from Chapter 9 to Chapter 17")
# Out:
# i. Discuss your learnings on from Chapter 9 to Chapter 17

# %%
print("Chapter 9: Minimum of 200 words")
print("A graph is a non-linear data structure. It consists of nodes and edges. Nodes are also known as vertices and edges or knows a s the line that connects the nodes. Its kind of similar to tree but in tree there should be only one path between two nodes. But in graphs you can randomly connect the nodes. Graphs are also used to represent networks. It is also used in social networks like Facebook, LinkedIn, Twitter and etc. For example, in Facebook a person represents a node and this node and this person can be connected to any person. Nodes contains information, it maybe id, name, location, or email. There are two types of graph which is directed graph and undirected graph. In directed graph, the nodes are connected directedly and only go in one direction. For example, for node 1 the arrow connects to node 2, therefore we can only go from node 1 to node 2 and can’t go to the other direction. In undirected graph, the nodes are connected bidirectional. For example, from node one to node 2 to node 3 and the from node 3 to node 2 to node 1, they go back and forth.")
# Out:
# Chapter 9: Minimum of 200 words
# ...

# %%
print("Chapter 10: Minimum of 200 words")
print("Binary search is a popular search algorithm that finds the element using log(n) time complexity. Binary search works in the concept of sorted list. Binary search looks for an item by comparing the middle item to left and right, if the item is greater than the middle, then the item is to be search in the right side of the item. But if the middle item is greater than the searched item then it is in the left side. For example, from 1 to 30 the searched item is 25. So, the middle item is 15, since 25 is greater than 15, lets try 16 to 30. The middle item is 23, still 25 is greater than 23. So, 24 to 30, the middle item is 27. Since 27 is greater than 25, it means the item search is in the left side. This means that it took 3 iterations to find 25 in the 1 to 30 numbers. It took less process than the linear search.")
# Out:
# Chapter 10: Minimum of 200 words
# Binary search is a popular search algorithm that finds the element using log(n) time complexity. Binary search works in the concept of sorted list. Binary search looks for an item by comparing the middle item to left and right, if the item is greater than the middle, then the item is to be search in the right side of the item. But if the middle item is greater than the searched item then it is in the left side. For example, from 1 to 30 the searched item is 25. So, the middle item is 15, since 25 is greater than 15, lets try 16 to 30. The middle item is 23, still 25 is greater than 23. So, 24 to 30, the middle item is 27. Since 27 is greater than 25, it means the item search is in the left side. This means that it took 3 iterations to find 25 in the 1 to 30 numbers. It took less process than the linear search.

# %%
print("Chapter 11: Minimum of 200 words")
print("Bubble sort is a simple sort program. The sorting concept is comparison-based where each pair are compared. The elements are swapped if they are not in order. For example, there is an array and it is not in order, they will continue to swap until they are not sorted in order. In number array, they are arranged and sorted which is greater than. Example the array is consists of 7, 6, 2, 5, 4, 3, 1, 8. If we sort this, since 7 is greater than 6 so they will have to swap. This becomes 6, 7, 2, 5, 4, 3, 1, 8. If we compare 2 and 7, 7 is greater and also 6 is greater than 2. This becomes 2, 6, 7, 5, 4, 3, 1, 8. We repeat the process until they are sorted out from least to greatest. After that the array becomes 1, 2, 3, 4, 5, 6, 7, 8. It is called simple sort because it has a simple concept of sorting data. It has a time complexity of 0(n^2) not that efficient but in terms of technique it is very simple to understand.")
# Out:
# Chapter 11: Minimum of 200 words
# Bubble sort is a simple sort program. The sorting concept is comparison-based where each pair are compared. The elements are swapped if they are not in order. For example, there is an array and it is not in order, they will continue to swap until they are not sorted in order. In number array, they are arranged and sorted which is greater than. Example the array is consists of 7, 6, 2, 5, 4, 3, 1, 8. If we sort this, since 7 is greater than 6 so they will have to swap. This becomes 6, 7, 2, 5, 4, 3, 1, 8. If we compare 2 and 7, 7 is greater and also 6 is greater than 2. This becomes 2, 6, 7, 5, 4, 3, 1, 8. We repeat the process until they are sorted out from least to greatest. After that the array becomes 1, 2, 3, 4, 5, 6, 7, 8. It is called simple sort because it has a simple concept of sorting data. It has a time complexity of 0(n^2) not that efficient but in terms of technique it is very simple to understand.

# %%
print("Chapter 12: Minimum of 200 words")
print("Quick sort is a popular sorting algorithm like merge sort it is a Divide and conquer algorithm. In the video, his example was the array 7, 9, 2, 11, 29, 15, 28. This array is not sorted yet. We select element 11 and call that as the pivot. And we will try to put the pivot to its right place. On the left side are elements that are smaller than 11 and on the right side are all greater than 11. Now, there are two partitions which the left partition and the right partition. On the left side there is 7, 9, 2 all you have to do is sort it since we don’t have to touch number 11. So, it becomes 2, 7, 9. Now we go to the right side which is 29, 15, 28. So here 29 becomes the pivot. Then we have to put the pivot to its right place. So, from 29, 15, 28 it now becomes 15, 28, 29. Now the elements are sorted from 7, 9, 2, 11, 29, 15, 28, we sorted it and it became 2, 7, 9, 11, 15, 28, 29. ")
# Out:
# Chapter 12: Minimum of 200 words
# Quick sort is a popular sorting algorithm like merge sort it is a Divide and conquer algorithm. In the video, his example was the array 7, 9, 2, 11, 29, 15, 28. This array is not sorted yet. We select element 11 and call that as the pivot. And we will try to put the pivot to its right place. On the left side are elements that are smaller than 11 and on the right side are all greater than 11. Now, there are two partitions which the left partition and the right partition. On the left side there is 7, 9, 2 all you have to do is sort it since we don’t have to touch number 11. So, it becomes 2, 7, 9. Now we go to the right side which is 29, 15, 28. So here 29 becomes the pivot. Then we have to put the pivot to its right place. So, from 29, 15, 28 it now becomes 15, 28, 29. Now the elements are sorted from 7, 9, 2, 11, 29, 15, 28, we sorted it and it became 2, 7, 9, 11, 15, 28, 29.

# %%
print("Chapter 13: Minimum of 200 words")
print("Insertion sort is also one of the simple sorting algorithms. It has a few lines of code and that is good for small lists. The concept is that in an array you look at the first two element. Look if they are sorted, if not then sort it out. So, the remining elements are unsorted. Look at the first unsorted element next to the sorted one. To imagine it more let’s use the videos example which is 21, 38, 29, 17, 4, 25, 11, 32, 9. In this case the 21 and 38 is a sorted side then we pick up 29 and insert it into 21 and 38 since 38 is greater than 29. This becomes 21, 29, 38, this is the sorted elements. The concept is there is a sorted side and unsorted side. We pick up one element from the unsorted side and insert it in the right place in the sorted. Why? To not break the order. We insert so that the order will not be messed not like the bubble sort. We swapped the elements until they were in the right order. It’s easier than the bubble sort because we will just insert the element. ")
# Out:
# Chapter 13: Minimum of 200 words
# ...

# %%
print("Chapter 14: Minimum of 200 words")
print("Merge sort is a very popular sort. This is also a short one. It performs better than the other sorts like insertion sort, bubble sort, quick sort and etc. Here, we suppose to have 1 array that is unsorted. We divide this array into two so that’s two arrays. And again, the two arrays, we split them again. After splitting there maybe pairs that is already sorted. Other pairs that is not sorted yet, we divide them again. Now we cross them and the other pairs are sorted then again, we merge the split first two arrays. So the two first array we split becomes sorted. This time the two arrays we merge them again but we sort them again until they become sorted in order. The code of this is also very easy and short. The concept is very easy that is why it is known as a popular sort. As I have said before this method of sorting is divide and conquer. Its worst time complexity is 0(n log n) it is one of the most respected algorithms. This makes it better that the other sorts. Again this sort divides into equal half and combines in sorted manner.")
# Out:
# Chapter 14: Minimum of 200 words
# ...

# %%
print("Chapter 15: Minimum of 200 words")
print("As the man said in the video, shell sort in also an important sort. Shell sort is an optimization over insertion sort. In insertion sort you keep on comparing the element until it reaches its correct position and that is the disadvantages. It has many swaps. In shell sort, it has this concept of having gaps. This creates a sub array depending on how big the gap is. Here, in the sub array you will sort in. instead of sorting in the entire array, we do it by sub array. And again, we move the sub array with the same gap. Meaning that shell sort has less swaps than the insertion array. In shell sort your last step is that you only have 1 gap. From a big gap to equal to one gap meaning this optimizes the swaps that the insertion sort has. That’s why in the first part he flashed the message that “Shell sort is an optimization over insertion sort” because it keeps on reducing.  It worst case performance is O(n^2) and its best case performance O(n log^2 n). the smaller value goes to the left and the heavy one is on the right side of the array.")
# Out:
# Chapter 15: Minimum of 200 words
# ...

# %%
print("Chapter 16: Minimum of 200 words")
print("Selection sort is another simple algorithm for sorting. Its concept is very easy. For example, you have an unsorted array. You find the small value of element an put it in the first one. That one element is part of the sorted array. Next, you will find the second small value element and then put it in the second place. Now it becomes part of the sorted array. It doesn’t matter if the small value element is in the last position or in the middle part. As long as it is the small one, put it in its right place in the sorted area. In other words, the smallest element is selected from the unsorted array and the swapped in the left area. The process keeps on repeating until the entire array becomes a sorted array. Even though this one is simple, it is still not suited for large data. The sorting is from ascending order also. From unsorted subarray to the sorted subarray.")
# Out:
# Chapter 16: Minimum of 200 words
# Selection sort is another simple algorithm for sorting. Its concept is very easy. For example, you have an unsorted array. You find the small value of element an put it in the first one. That one element is part of the sorted array. Next, you will find the second small value element and then put it in the second place. Now it becomes part of the sorted array. It doesn’t matter if the small value element is in the last position or in the middle part. As long as it is the small one, put it in its right place in the sorted area. In other words, the smallest element is selected from the unsorted array and the swapped in the left area. The process keeps on repeating until the entire array becomes a sorted array. Even though this one is simple, it is still not suited for large data. The sorting is from ascending order also. From unsorted subarray to the sorted subarray.

# %%
print("Chapter 17: Minimum of 200 words")
print("Recursion is a very important concept. From the video he said that any problem can be divided into small and simpler problem. In recursion a function can directly call itself or call another function and then call the original function. That is called as recursive function. Base on his example, the person calls the person in front to ask how many breads they have to add to the number of their bread. From Meera to Sheila to Aarav to Yana to Madhav. The manner of the person calls another person just like what I said. A function calling another function. It calls itself one or more times to meet a certain condition and that is the problem that was given to the waiting customers which is to total the breads in front of them including the ones that was with them. Recursive has a certain structure and first is a base case, second is a recursive step which calls itself until its close to the base case.")
# Out:
# Chapter 17: Minimum of 200 words
# Recursion is a very important concept. From the video he said that any problem can be divided into small and simpler problem. In recursion a function can directly call itself or call another function and then call the original function. That is called as recursive function. Base on his example, the person calls the person in front to ask how many breads they have to add to the number of their bread. From Meera to Sheila to Aarav to Yana to Madhav. The manner of the person calls another person just like what I said. A function calling another function. It calls itself one or more times to meet a certain condition and that is the problem that was given to the waiting customers which is to total the breads in front of them including the ones that was with them. Recursive has a certain structure and first is a base case, second is a recursive step which calls itself until its close to the base case.

# %%
print("ii. Answer the following questions:")
# Out:
# ii. Answer the following questions:

# %%
print("1. Implement the simple methods get_num and get_den that will return the numerator and denominator of a fraction.")
print("\n")
class Fraction:

    def __init__(self, up, down):

        self.num = up
        self.den = down

    def __str__(self):
        return str(self.num) + "/" + str(self.den)

    def get_num(self):
        return self.num

    def get_den(self):
        return self.den

frac = Fraction(4, 8)
print(frac)

print(frac.get_num())
print(frac.get_den())
# Out:
# 1. Implement the simple methods get_num and get_den that will return the numerator and denominator of a fraction.
#
#
# 4/8
# 4
# 8

# %%
print("2. Research the __radd__ method. How does it differ from __add__? When is it used? Implement __radd__")
print("")
print("the __add__ method adds the same type of elements but if its not the same it raises an error thats where __radd__ comes in. Instead of raising a type error it executes the program smoothly")
print("")
class one:
    def __init__(self, value):
        self.value = value


class two:
    def __init__(self, value):
        self.value = value

    def __radd__(self, other):
        return self.value + other.value


a = one(2)
b = two(5)

print(a + b)
# Out:
# 2. Research the __radd__ method. How does it differ from __add__? When is it used? Implement __radd__
#
# the __add__ method adds the same type of elements but if its not the same it raises an error thats where __radd__ comes in. Instead of raising a type error it executes the program smoothly
#
# 7

# %%
print("3. Research the __repr__ method. How does it differ from __str__? When is it used? Implement __repr__.")
print("-__repr__ computes the string representation of an object while __str__ is used for creating output for end user. __repr__ id main used for debugging and development\n")
print("")

class Student:

    def __init__(self, name, number):
        self.name = name
        self.number = number

    def __str__(self):
        return f'Student name is {self.name} and ID number is {self.number}'

    def __repr__(self):
        return f'(Student Name={self.name}, ID number={self.number})'


s = Student('Krishia', 2020302916)

print(s.__str__())
print(s.__repr__())
# Out:
# 3. Research the __repr__ method. How does it differ from __str__? When is it used? Implement __repr__.
# -__repr__ computes the string representation of an object while __str__ is used for creating output for end user. __repr__ id main used for debugging and development
#
#
# Student name is Krishia and ID number is 2020302916
# (Student Name=Krishia, ID number=2020302916)

# %%
print("4. The most simple arithmetic circuit is known as the half adder. Research the simple half-adder circuit. Implement this circuit")
print("")
def getResult(K, M):
    # Calculating value of sum
    Sum = K ^ M

    # Calculating value of Carry
    Carry = K & M

    # printing the values
    print("Sum ", Sum)
    print("Carry", Carry)


# Driver code
K = 0
M = 1

# passing two inputs of halfadder as arguements to get result function
getResult(K, M)
# Out:
# 4. The most simple arithmetic circuit is known as the half adder. Research the simple half-adder circuit. Implement this circuit

# %%
print("5. Design a class to represent a playing card and another one to represent a deck of cards. Using these two classes, implement your favorite card game.")
print("")
import random


class Card(object):
    def __init__(self, suit, val):
        self.suit = suit
        self.value = val

    # Implementing build in methods so that you can print a card object
    def __unicode__(self):
        return self.show()

    def __str__(self):
        return self.show()

    def __repr__(self):
        return self.show()

    def show(self):
        if self.value == 1:
            val = "Ace"
        elif self.value == 11:
            val = "Jack"
        elif self.value == 12:
            val = "Queen"
        elif self.value == 13:
            val = "King"
        else:
            val = self.value

        return "{} of {}".format(val, self.suit)


class Deck(object):
    def __init__(self):
        self.cards = []
        self.build()

    # Display all cards in the deck
    def show(self):
        for card in self.cards:
            print(card.show())

    # Generate 52 cards
    def build(self):
        self.cards = []
        for suit in ['Hearts', 'Clubs', 'Diamonds', 'Spades']:
            for val in range(1, 14):
                self.cards.append(Card(suit, val))

    # Shuffle the deck
    def shuffle(self, num=1):
        length = len(self.cards)
        for _ in range(num):
            # This is the fisher yates shuffle algorithm
            for i in range(length - 1, 0, -1):
                randi = random.randint(0, i)
                if i == randi:
                    continue
                self.cards[i], self.cards[randi] = self.cards[randi], self.cards[i]
            # You can also use the build in shuffle method
            # random.shuffle(self.cards)

    # Return the top card
    def deal(self):
        return self.cards.pop()


class Player(object):
    def __init__(self, name):
        self.name = name
        self.hand = []

    def sayHello(self):
        print("Hi! My name is {}".format(self.name))
        return self

    # Draw n number of cards from a deck
    # Returns true in n cards are drawn, false if less then that
    def draw(self, deck, num=1):
        for _ in range(num):
            card = deck.deal()
            if card:
                self.hand.append(card)
            else:
                return False
        return True

    # Display all the cards in the players hand
    def showHand(self):
        print("{}'s hand: {}".format(self.name, self.hand))
        return self

    def discard(self):
        return self.hand.pop()


# Test making a Card
# card = Card('Spades', 6)
# print card

# Test making a Deck
myDeck = Deck()
myDeck.shuffle()
# deck.show()

bob = Player("Bob")
bob.sayHello()
bob.draw(myDeck, 5)
bob.showHand()
# Out:
# 5. Design a class to represent a playing card and another one to represent a deck of cards. Using these two classes, implement your favorite card game.
#
# Hi! My name is Bob
# Bob's hand: [4 of Hearts, Ace of Hearts, 4 of Clubs, Jack of Spades, 9 of Clubs]

# %%
print("6. Design and implement an experiment to do benchmark comparisons of the two queue(enqueue,dequeue) implementations. What can you learn from such an experiment?Create a program code using enqueue and dequeue then compare.")
print("")

class Queue:

    def __init__(self):
        self.queue = []

    # Add an element
    def enqueue(self, item):
        self.queue.append(item)

    # Remove an element
    def dequeue(self):
        if len(self.queue) < 1:
            return None
        return self.queue.pop(3)


    # Display  the queue
    def display(self):
        print(self.queue)

    def size(self):
        return len(self.queue)


q = Queue()
q.enqueue(2)
q.enqueue(4)
q.enqueue(6)
q.enqueue(8)
q.enqueue(10)

q.display()

q.dequeue()
print("Removed")
q.display()

print("the enqueue adds an element while dequeque removes and element by the index number")
# Out:
# 6. Design and implement an experiment to do benchmark comparisons of the two queue(enqueue,dequeue) implementations. What can you learn from such an experiment?Create a program code using enqueue and dequeue then compare.
#
# [2, 4, 6, 8, 10]
# Removed
# [2, 4, 6, 10]
# the enqueue adds an element while dequeque removes and element by the index number

# %%
print("7. Consider a real life situation. Formulate a question and then design a simulation that can help to answer it. Possible situations include:\na. Cars lined up at a car wash\nb.Customers at a grocery store check-out\nc.Airplanes taking off and landing on a runway\nd.A bank teller\nBe sure to state any assumptions that you make and provide any probabilistic data that must be considered as part of the scenario.No more coding for this item, just explanation.")
print("")
print("Answers:")
print("a. Question: How fast does the machine cleans the car?")
print("-example, the cars are lined up in a car wash. Now it only depends in how fast the machine can clean up the car.\n")
print("b. Question: How much time does it take for a cashier to finish everything from punching down the items to packing it up?")
print("- in a grocery people line up to pay for their items. So whoever comes first will be done first.\n")
print("c. Question: How much time does it take for a plane to take off and land on the runway?")
print("- if the planes are waiting for another plane to take off for another plane to land on the runway, it now depends on the speed of the airplane.\n")
print("d. How much time does it take to finish one costumer in one teller?")
print("- in a bank, tellers have to call a person one by one and it now depends on how quick is the transaction to finish\n")
# Out:
# 7. Consider a real life situation. Formulate a question and then design a simulation that can help to answer it. Possible situations include:
# a. Cars lined up at a car wash
# b.Customers at a grocery store check-out
# c.Airplanes taking off and landing on a runway
# d.A bank teller
# Be sure to state any assumptions that you make and provide any probabilistic data that must be considered as part of the scenario.No more coding for this item, just explanation.
#
# Answers:
# a. Question: How fast does the machine cleans the car?
# -example, the cars are lined up in a car wash. Now it only depends in how fast the machine can clean up the car.
#
# b. Question: How much time does it take for a cashier to finish everything from punching down the items to packing it up?
# - in a grocery people line up to pay for their items. So whoever comes first will be done first.
#
# c. Question: How much time does it take for a plane to take off and land on the runway?
# ...

# %%
print("8. Implement a queue using linked lists.")
print("")
class Node:

    def __init__(self, data):
        self.data = data
        self.next = None


# A class to represent a queue
class Queue:

    def __init__(self):
        self.front = self.rear = None

    def isEmpty(self):
        return self.front == None

    # Method to add an item to the queue
    def EnQueue(self, item):
        temp = Node(item)

        if self.rear == None:
            self.front = self.rear = temp
            return
        self.rear.next = temp
        self.rear = temp

    # Method to remove an item from queue
    def DeQueue(self):

        if self.isEmpty():
            return
        temp = self.front
        self.front = temp.next

        if (self.front == None):
            self.rear = None


# Driver Code
if __name__ == '__main__':
    q = Queue()
    q.EnQueue(20)
    q.EnQueue(40)
    q.DeQueue()
    q.DeQueue()
    q.EnQueue(60)
    q.EnQueue(80)
    q.EnQueue(100)
    q.DeQueue()
    print("Front " + str(q.front.data))
    print("Rear " + str(q.rear.data))
# Out:
# 8. Implement a queue using linked lists.
#
# Front 80
# Rear 100

# %%
print("9. Write a recursive function to compute the factorial of a number.")
print(" ")
def factorial(n):
   if n == 1:
       return n
   else:
       return n*factorial(n-1)

num = 8
print("The factorial of", num, "is", factorial(num))
# Out:
# 9. Write a recursive function to compute the factorial of a number.
#
# The factorial of 8 is 40320

# %%
print("10. Set up a random experiment to test the difference between a sequential search and a binary search on a list of integers.")
print("")
def binarySearch(arr, l, r, x):
    # Check base case
    if r >= l:

        mid = l + (r - l) // 2

        # If element is present at the middle itself
        if arr[mid] == x:
            return mid

        # If element is smaller than mid, then it
        # can only be present in left subarray
        elif arr[mid] > x:
            return binarySearch(arr, l, mid - 1, x)

        
        else:
            return binarySearch(arr, mid + 1, r, x)

    else:
        # Element is not present in the array
        return -1


# Driver Code
arr = [2, 3, 4, 10, 40]
x = 10

# Function call
result = binarySearch(arr, 0, len(arr) - 1, x)

if result != -1:
    print("Element is present at index % d" % result)
else:
    print("Element is not present in array")


def Sequential_Search(dlist, item):
    pos = 0
    found = False

    while pos < len(dlist) and not found:
        if dlist[pos] == item:
            found = True
        else:
            pos = pos + 1

    return found, pos


print(Sequential_Search([21, 15, 90, 50, 6, 23, 44, 12, 11, 4], 6))
print("")
print("Binary search finds the element by dividing the interval into half to narrow it down until it finds the element while in sequential search it checks each element to find the particular value until it finds the element")
# Out:
# 10. Set up a random experiment to test the difference between a sequential search and a binary search on a list of integers.
#
# Element is present at index  3
# (True, 4)
#
# Binary search finds the element by dividing the interval into half to narrow it down until it finds the element while in sequential search it checks each element to find the particular value until it finds the element

# %%
print("11. Suppose you are a computer scientist/art thief who has broken into a major art gallery. All you have with you to haul out your stolen art is your knapsack which only holds W pounds of art, but for every piece of art you know its value and its weight. Write a dynamic programming function to help you maximize your profit. Here is a sample problem for you to use to get started: Suppose your knapsack can hold a total weight of 20. You have 5 items as follows:")
print("\n")
val = [3, 4, 8, 8, 10 ]
wt = [2, 3, 4, 5, 9 ]
W = 20
n = len(val)
 
t = [[-1 for i in range(W + 1)] for j in range(n + 1)]
 

def knapsack(wt, val, W, n):

    if n == 0 or W == 0:
        return 0
    if t[n][W] != -1:
        return t[n][W]
 
    if wt[n-1] <= W:
        t[n][W] = max(
            val[n-1] + knapsack(
                wt, val, W-wt[n-1], n-1),
            knapsack(wt, val, W, n-1))
        return t[n][W]
    elif wt[n-1] > W:
        t[n][W] = knapsack(wt, val, W, n-1)
        return t[n][W]
 
 
print(knapsack(wt, val, W, n))
# Out:
# 11. Suppose you are a computer scientist/art thief who has broken into a major art gallery. All you have with you to haul out your stolen art is your knapsack which only holds W pounds of art, but for every piece of art you know its value and its weight. Write a dynamic programming function to help you maximize your profit. Here is a sample problem for you to use to get started: Suppose your knapsack can hold a total weight of 20. You have 5 items as follows:
#
#
# 29
